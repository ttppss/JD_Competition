# %% [markdown]
# # Read in csv files and take a look at them

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ads = pd.read_csv("../t_ads.csv", dtype={'create_dt': object, 'charge': float, 'consume': float, 'shop_id': int})
comment = pd.read_csv("../t_comment.csv", dtype={'create_dt': object, 'bad_num': int, 'cmmt_num': int, 'dis_num': int, 'good_num': int, 'mid_num': int, 'shop_id': int})
order = pd.read_csv("../t_order.csv", dtype={'ord_dt': object, 'sale_amt': float, 'offer_amt': float, 'offer_cnt': int, 'shop_id': int, 'rtn_cnt': int, 'rtn_amt': float, 'ord_cnt': int, 'pid': int, 'user_cnt': int})
product = pd.read_csv("../t_product.csv", dtype={'on_dt': object, 'off_dt': object, 'brand': int, 'cate': int, 'shop_id': int, 'pid': int})
sales_sum = pd.read_csv("../t_sales_sum.csv", dtype={'dt': object, 'shop_id': int, 'sle_amt_3m': float})

# %%
ads.head()
# Out:
#     create_dt   charge   consume  shop_id
# 0  2016-08-22      0.0   9110.21     1036
# 1  2016-08-31      0.0     95.95     1036
# 2  2016-09-12      0.0   1085.23     1036
# 3  2016-09-30  65298.6  25096.86     1036
# 4  2016-12-18      0.0  18974.81     1036

# %%
ads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226128 entries, 0 to 226127
# Data columns (total 4 columns):
# create_dt    226128 non-null object
# charge       226128 non-null float64
# consume      226128 non-null float64
# shop_id      226128 non-null int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 6.9+ MB

# %%
ads.describe()
# Out:
#              charge       consume        shop_id
# count  2.261280e+05  2.261280e+05  226128.000000
# mean   6.766189e+05  2.147743e+04    1491.978070
# std    2.827599e+08  4.783401e+04     862.851081
# min    0.000000e+00  0.000000e+00       1.000000
# 25%    0.000000e+00  1.209428e+03     724.000000
# 50%    0.000000e+00  7.388940e+03    1517.000000
# 75%    0.000000e+00  2.245244e+04    2222.000000
# max    1.339081e+11  3.526154e+06    2998.000000

# %%
comment.head()
# Out:
#     create_dt  bad_num  cmmt_num  dis_num  good_num  mid_num  shop_id
# 0  2016-08-07        0         2        0         2        0     1494
# 1  2017-01-10        0        21        0        21        0     1494
# 2  2017-02-19        0        14        1        14        0     1494
# 3  2017-03-09        0        14        0        14        0     1494
# 4  2016-09-13        2       174        0       172        0     1036

# %%
comment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636206 entries, 0 to 636205
# Data columns (total 7 columns):
# create_dt    636206 non-null object
# bad_num      636206 non-null int64
# cmmt_num     636206 non-null int64
# dis_num      636206 non-null int64
# good_num     636206 non-null int64
# mid_num      636206 non-null int64
# shop_id      636206 non-null int64
# dtypes: int64(6), object(1)
# memory usage: 34.0+ MB

# %%
comment.describe()
# Out:
#              bad_num       cmmt_num        dis_num       good_num  \
# count  636206.000000  636206.000000  636206.000000  636206.000000
# mean        0.416005      45.251532       1.261106      44.360838
# std         2.303277     162.533671       7.129115     162.321697
# min         0.000000       1.000000       0.000000       0.000000
# 25%         0.000000       3.000000       0.000000       2.000000
# 50%         0.000000       8.000000       0.000000       8.000000
# 75%         0.000000      30.000000       1.000000      29.000000
# max      1025.000000   18364.000000    1579.000000   18364.000000
#
#              mid_num        shop_id
# count  636206.000000  636206.000000
# mean        0.474689    1496.159093
# std         1.667023     863.838409
# min         0.000000       1.000000
# 25%         0.000000     748.000000
# 50%         0.000000    1498.000000
# 75%         0.000000    2242.000000
# max       309.000000    3000.000000

# %%
order.head()
# Out:
#        ord_dt  sale_amt  offer_amt  offer_cnt  shop_id  rtn_cnt  rtn_amt  \
# 0  2016-09-04     19.82        0.0          0     1630        0      0.0
# 1  2017-01-02     19.82        0.0          0     1630        0      0.0
# 2  2016-09-23     19.82        0.0          0     1630        0      0.0
# 3  2016-12-29     19.82        0.0          0     1630        0      0.0
# 4  2016-08-26     19.82        0.0          0     1630        0      0.0
#
#    ord_cnt  pid  user_cnt
# 0        1   41         1
# 1        1   41         1
# 2        1   49         1
# 3        1   49         1
# 4        1   59         1

# %%
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12098397 entries, 0 to 12098396
# Data columns (total 10 columns):
# ord_dt       object
# sale_amt     float64
# offer_amt    float64
# offer_cnt    int64
# shop_id      int64
# rtn_cnt      int64
# rtn_amt      float64
# ord_cnt      int64
# pid          int64
# user_cnt     int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 923.0+ MB

# %%
order.describe()
# Out:
#            sale_amt     offer_amt     offer_cnt       shop_id       rtn_cnt  \
# count  1.209840e+07  1.209840e+07  1.209840e+07  1.209840e+07  1.209840e+07
# mean   1.351284e+02  3.634498e+01  1.075041e+00  1.484875e+03  4.117165e-02
# std    3.114573e+02  3.702764e+02  3.890224e+00  8.611823e+02  2.367994e-01
# min   -9.812300e+02  0.000000e+00  0.000000e+00  1.000000e+00  0.000000e+00
# 25%    3.304000e+01  0.000000e+00  0.000000e+00  7.340000e+02  0.000000e+00
# 50%    7.268000e+01  1.100000e+00  1.000000e+00  1.510000e+03  0.000000e+00
# 75%    1.313300e+02  2.060000e+01  1.000000e+00  2.233000e+03  0.000000e+00
# max    1.969077e+05  3.681660e+05  2.010000e+03  3.000000e+03  6.800000e+01
#
#             rtn_amt       ord_cnt           pid      user_cnt
# count  1.209840e+07  1.209840e+07  1.209840e+07  1.209840e+07
# mean   2.372422e+00  1.919387e+00  5.770331e+06  1.915682e+00
# std    2.081579e+01  4.731932e+00  4.437023e+06  4.718645e+00
# ...

# %%
product.head()
# Out:
#         on_dt off_dt  brand  cate  shop_id  pid
# 0  2015-10-27    NaN    425   129     1873   11
# 1  2014-10-16    NaN   2100   264       91   23
# 2  2015-10-27    NaN    107   238     2107   77
# 3  2014-08-22    NaN   2100   262       91   99
# 4  2014-08-22    NaN   2100   262       91  110

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11398239 entries, 0 to 11398238
# Data columns (total 6 columns):
# on_dt      object
# off_dt     object
# brand      int64
# cate       int64
# shop_id    int64
# pid        int64
# dtypes: int64(4), object(2)
# memory usage: 521.8+ MB

# %%
product.describe()
# Out:
#               brand          cate       shop_id           pid
# count  1.139824e+07  1.139824e+07  1.139824e+07  1.139824e+07
# mean   1.430943e+03  2.108172e+02  1.511352e+03  7.085523e+06
# std    8.858200e+02  6.306873e+01  8.159483e+02  3.895864e+06
# min    1.000000e+00  1.000000e+00  1.000000e+00  2.000000e+00
# 25%    6.850000e+02  2.160000e+02  8.190000e+02  3.693910e+06
# 50%    1.368000e+03  2.230000e+02  1.538000e+03  7.334471e+06
# 75%    2.148000e+03  2.490000e+02  2.253000e+03  1.048121e+07
# max    3.089000e+03  3.100000e+02  3.000000e+03  1.370726e+07

# %%
sales_sum.head()
# Out:
#            dt  shop_id  sale_amt_3m
# 0  2016-12-31     2143     72983.09
# 1  2016-07-31     2143    106943.03
# 2  2016-08-31     2143    183723.36
# 3  2016-09-30     2143    235568.57
# 4  2016-11-30     2143     80115.29

# %%
sales_sum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24030 entries, 0 to 24029
# Data columns (total 3 columns):
# dt             24030 non-null object
# shop_id        24030 non-null int64
# sale_amt_3m    24030 non-null float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 563.3+ KB

# %%
sales_sum.describe()
# Out:
#             shop_id    sale_amt_3m
# count  24030.000000   24030.000000
# mean    1501.376363  166906.943563
# std      865.857626  157007.255156
# min        1.000000    8287.630000
# 25%      751.250000   52251.887500
# 50%     1502.000000  110842.825000
# 75%     2249.750000  229571.560000
# max     3000.000000  825691.940000

# %% [markdown]
# # Data Visualization

# %%
g = sns.barplot(x = 'create_dt', y = 'consume', data = ads)
g.set_xticklabels(g.get_xticklabels(), rotation=90)

# %%
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12098397 entries, 0 to 12098396
# Data columns (total 10 columns):
# ord_dt       object
# sale_amt     float64
# offer_amt    float64
# offer_cnt    int64
# shop_id      int64
# rtn_cnt      int64
# rtn_amt      float64
# ord_cnt      int64
# pid          int64
# user_cnt     int64
# dtypes: float64(3), int64(6), object(1)
# memory usage: 923.0+ MB

# %%
order.isnull().sum()
# Out:
# ord_dt       0
# sale_amt     0
# offer_amt    0
# offer_cnt    0
# shop_id      0
# rtn_cnt      0
# rtn_amt      0
# ord_cnt      0
# pid          0
# user_cnt     0
# dtype: int64

# %%
sales_sum.isnull().sum()
# Out:
# dt             0
# shop_id        0
# sale_amt_3m    0
# dtype: int64

# %%
comment.isnull().sum()
# Out:
# create_dt    0
# bad_num      0
# cmmt_num     0
# dis_num      0
# good_num     0
# mid_num      0
# shop_id      0
# dtype: int64

# %%
product.isnull().sum()
# Out:
# on_dt             0
# off_dt     11297557
# brand             0
# cate              0
# shop_id           0
# pid               0
# dtype: int64

# %%
ads.isnull().sum()
# Out:
# create_dt    0
# charge       0
# consume      0
# shop_id      0
# dtype: int64

# %%
sales_sum['shop_id'].value_counts()
# Out:
# 2205    37
# 2129     9
# 2500     8
# 517      8
# 2564     8
# 501      8
# 2548     8
# 485      8
# 2532     8
# 469      8
# 2516     8
# 453      8
# 437      8
# 533      8
# 2484     8
# 421      8
# 2468     8
# 405      8
# 2452     8
# 389      8
# 2436     8
# 373      8
# 2420     8
# 2580     8
# 2047     8
# 2404     8
# 629      8
# 2756     8
# 693      8
# 2740     8
#         ..
# 2827     8
# 778      8
# 2811     8
# 762      8
# 2795     8
# 746      8
# 2939     8
# 2955     8
# 1210     8
# 922      8
# 1194     8
# 1178     8
# 1162     8
# 1146     8
# 1130     8
# 1114     8
# 1098     8
# 1082     8
# 1066     8
# 1050     8
# 1034     8
# 1018     8
# 1002     8
# 986      8
# 970      8
# 954      8
# 2987     8
# 938      8
# 2971     8
# 2049     8
# Name: shop_id, Length: 3000, dtype: int64

# %%
#Attention, shop_id = 2205 has multiple duplicated values
sales_sum[sales_sum['shop_id'] == 2205]
# Out:
#                dt  shop_id  sale_amt_3m
# 8787   2016-12-31     2205     26176.17
# 8788   2016-12-31     2205     26176.17
# 8789   2016-12-31     2205     26176.17
# 8790   2016-12-31     2205     26176.17
# 8791   2016-12-31     2205     26176.17
# 8792   2016-08-31     2205    381463.75
# 8793   2017-01-31     2205     17885.23
# 8794   2017-01-31     2205     17885.23
# 8795   2017-01-31     2205     17885.23
# 8796   2017-01-31     2205     17885.23
# 8797   2017-01-31     2205     17885.23
# 8798   2017-01-31     2205     17885.23
# 8799   2017-01-31     2205     17885.23
# 8800   2017-01-31     2205     17885.23
# 8801   2016-11-30     2205     97464.37
# 8802   2016-11-30     2205     97464.37
# 8803   2016-11-30     2205     97464.37
# 8804   2016-11-30     2205     97464.37
# 8805   2016-10-31     2205    216914.84
# 20835  2016-06-30     2205    304523.21
# 20836  2016-12-31     2205     26176.17
# 20837  2016-12-31     2205     26176.17
# ...

# %%
sales_sum[sales_sum['shop_id'] == 2129]
# Out:
#                dt  shop_id  sale_amt_3m
# 9185   2016-12-31     2129    181218.42
# 9186   2016-12-31     2129    181218.42
# 9187   2017-01-31     2129    132349.58
# 9188   2016-11-30     2129    265358.35
# 9189   2016-10-31     2129    443907.25
# 21218  2016-06-30     2129    252884.77
# 21219  2016-07-31     2129    327942.55
# 21220  2016-08-31     2129    459830.10
# 21221  2016-09-30     2129    435947.69

# %%
sales_sum_without_duplicates = sales_sum.drop_duplicates()

# %%
#already dropped duplicated rows for sales_sum dataframe
sales_sum_without_duplicates['shop_id'].value_counts().nunique()
# Out:
# 1

# %% [markdown]
# # Take a look at the shape of all those dataframes

# %%
product.shape
# Out:
# (11398239, 6)

# %%
comment.shape
# Out:
# (636206, 7)

# %%
order.shape
# Out:
# (12098397, 10)

# %%
sales_sum_without_.shape
# Out:
# (24030, 3)

# %%
ads.shape
# Out:
# (226128, 4)

# %% [markdown]
# # Join order with product

# %%
order_product = pd.merge(order, product, how='left', on=['pid', 'shop_id'])

# %%
order_product.head()
# Out:
#        ord_dt  sale_amt  offer_amt  offer_cnt  shop_id  rtn_cnt  rtn_amt  \
# 0  2016-09-04     19.82        0.0          0     1630        0      0.0
# 1  2017-01-02     19.82        0.0          0     1630        0      0.0
# 2  2016-09-23     19.82        0.0          0     1630        0      0.0
# 3  2016-12-29     19.82        0.0          0     1630        0      0.0
# 4  2016-08-26     19.82        0.0          0     1630        0      0.0
#
#    ord_cnt  pid  user_cnt on_dt off_dt  brand  cate
# 0        1   41         1   NaN    NaN    NaN   NaN
# 1        1   41         1   NaN    NaN    NaN   NaN
# 2        1   49         1   NaN    NaN    NaN   NaN
# 3        1   49         1   NaN    NaN    NaN   NaN
# 4        1   59         1   NaN    NaN    NaN   NaN

# %%
product[product['pid'] == 41]
# Out:
# Empty DataFrame
# Columns: [on_dt, off_dt, brand, cate, shop_id, pid]
# Index: []

# %%
order_product.isnull().sum()
# Out:
# ord_dt              0
# sale_amt            0
# offer_amt           0
# offer_cnt           0
# shop_id             0
# rtn_cnt             0
# rtn_amt             0
# ord_cnt             0
# pid                 0
# user_cnt            0
# on_dt         8864383
# off_dt       12097854
# brand         8864383
# cate          8864383
# dtype: int64

# %% [markdown]
# From the result above, we can see that some products are in order dataframe, but not in product dataframe, and that's a lot, amlost 2/3 of the orders are not in product dataframe.
#
# And almost all those products do not have a off-shelf date, so maybe we can delete this column at last.

# %% [markdown]
# # Join order_product with comment

# %%
order_product_comment = pd.merge(order_product, comment, how='left', on='shop_id')
